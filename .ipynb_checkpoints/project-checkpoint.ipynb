# %%
pip install os
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: No matching distribution found for os
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
from deepface import DeepFace

# %%
import matplotlib.pyplot as plt
img = cv2.imread('happyboy2.webp')
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))##for coloring image

# %%
predictions= DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 2.1081108414477967e-06,
#   'disgust': 5.2004997259502e-12,
#   'fear': 2.2767454588290548e-08,
#   'happy': 99.64244961738586,
#   'sad': 4.023442556899681e-05,
#   'surprise': 9.618610192774213e-05,
#   'neutral': 0.3574165515601635},
#  'dominant_emotion': 'happy',
#  'region': {'x': 183, 'y': 28, 'w': 228, 'h': 228},
#  'age': 25,
#  'gender': 'Man',
#  'race': {'asian': 1.1971623539824399e-14,
#   'indian': 7.835550242495104e-11,
#   'black': 100.0,
#   'white': 5.789528791828489e-19,
#   'middle eastern': 2.9345065873279745e-18,
#   'latino hispanic': 1.0440531495988295e-12},
#  'dominant_race': 'black'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# print (faceCascade.empty())
faces=faceCascade.detectMultiScale(gray,1.1,4)

# draw a rectangle around the face
for(x , y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX

#USE PUTTEXT() METHOD FOR
# INSERTING TEXT ON IMG
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad_woman.webp')
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions= DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:00<00:00,  5.35it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 4.454600811004639,
#   'disgust': 0.6230450235307217,
#   'fear': 5.8912161737680435,
#   'happy': 0.02302824577782303,
#   'sad': 84.208083152771,
#   'surprise': 0.00030950318432587665,
#   'neutral': 4.799716919660568},
#  'dominant_emotion': 'sad',
#  'region': {'x': 384, 'y': 73, 'w': 273, 'h': 273},
#  'age': 30,
#  'gender': 'Woman',
#  'race': {'asian': 6.509769707918167,
#   'indian': 3.8902699947357178,
#   'black': 1.0857055895030499,
#   'white': 42.03020632266998,
#   'middle eastern': 14.599177241325378,
#   'latino hispanic': 31.884878873825073},
#  'dominant_race': 'white'}

# %%
import cv2
from deepface import DeepFace
# import os

from playsound import playsound

faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades+'haarcascade_frontalface_default.xml')

cap=cv2.VideoCapture(1)
#check if webcam is open correctly or not

if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("cannot open webcam")

# file = open("path to file you want to save your results in", 'w')

# # giving directory for your pictures
# dirname = "the path of the directory"
  
# for files in os.listdir(dirname):
#     try:
#         obj = DeepFace.analyze(img_path = ("the path of the directory" + files), actions = ['age', 'gender', 'race', 'emotion'])
#         file.write(files)
#         file.write(str(obj) + "\n")
#     except Exception: 
#         file.write(files)
#         file.write("face_was not detected" + "\n")
# file.close()
    
while True:
    ret,frame=cap.read()# read one image from video
    
    result=DeepFace.analyze(frame, actions=['emotion'])
    
    #to draw a rectangle across the face
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    

    face=faceCascade.detectMultiScale(gray,1.1,4)
    
    for(x,y,w,h) in face:
        cv2.rectangle(frame, (x,y), (x+w , y+h), (0,255,0), 2)
    
    
    font=cv2.FONT_HERSHEY_SIMPLEX
    #inserting text on video
    cv2.putText(frame,
               result['dominant_emotion'],
               (50,50), 
               font, 3,
               (0,0,255),
               2,
               cv2.LINE_4)
    cv2.imshow('Original video',frame)
    path=result['dominant_emotion']+".mp3"
    playsound(path)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
path=result['dominant_emotion']+".mp3"
playsound(path)
#print(path)
# Out:
# neutral

# %%
type(path)
# Out:
# str

# %%
path=path+".mp3"
print(path)
# Out:
# neutral.mp3

# %%
playsound(path)
